# %% [markdown]
# # Introduction to GDeltCryptoNewsDownload Notebook
#
# The purpose of this Jupyter notebook is to demonstrate the process of collecting and consolidating a dataset of news articles related to cryptocurrencies from the Global Database of Events, Language, and Tone (GDELT) project. This dataset, referred to as `GA_data.csv`, is intended for use in risk and fraud analysis projects where understanding the impact of news on the cryptocurrency market is crucial.
#
# ## Objective
#
# To automate the retrieval of news articles from the GDELT database, focusing specifically on content related to various cryptocurrencies over a specified time period. This involves filtering articles by keywords associated with the cryptocurrency market, such as "cryptocurrency", "Bitcoin", "Ethereum", and others, to ensure the dataset is relevant to the project's needs.
#
# ## Methodology
#
# The notebook utilizes the `gdeltdoc` Python library to interact with the GDELT database. This library simplifies the process of searching for and downloading news articles by providing a structured approach to specify search criteria (e.g., keywords, date ranges).
#
# ### Key Steps:
#
# 1. **Setting Up Filters**: Define a set of filters using the `Filters` class from the `gdeltdoc` library. These filters specify the keywords to search for (e.g., "crypto", "Bitcoin", "Ethereum", etc.) and the date range for the search. The date range is dynamically set to cover the period from the current day to the previous day to ensure the dataset is continually updated with the most recent news.
#
# 2. **Searching for Articles**: Execute a search query against the GDELT database using the defined filters. The search results are filtered to include only articles in English to maintain consistency in the dataset.
#
# 3. **Consolidating and Cleaning the Data**: The search results are compiled into a pandas DataFrame, with duplicates (based on article URLs) removed to ensure each article is unique. This step is repeated for each keyword and each day in the specified period, resulting in a comprehensive dataset of cryptocurrency-related news.
#
# 4. **Output**: The final DataFrame, containing unique news articles related to the specified keywords and within the given time frame, is saved to a CSV file named `GA_data.csv`. This file serves as the primary dataset for further analysis in the risk and fraud project.
#
# ## Usage
#
# This notebook is designed to be executed on a regular basis (e.g., daily) to update the `GA_data.csv` file with the latest news articles. Users can modify the keyword list and the date range as needed to tailor the dataset to their specific project requirements.
#
# ## Requirements
#
# - Python 3.x
# - Pandas library
# - GDELTDoc library (`gdeltdoc`)
#
# ## Conclusion
#
# By leveraging the GDELT project's extensive database of global news articles, this notebook provides a streamlined process for collecting and preparing a dataset specifically focused on the cryptocurrency market. This dataset is invaluable for conducting risk and fraud analysis, offering insights into how news coverage can influence market behavior and potentially uncovering patterns or trends that could indicate fraudulent activities.

# %% [markdown]
# ---
# ## Library Instalation for all 5 notebooks in the project

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ---

# %%
## Imports
from datetime import date, timedelta, datetime
import pandas as pd
from gdeltdoc import GdeltDoc, Filters
import time

# %%
start_date = datetime.strptime('31/01/2024 00:00:00', '%d/%m/%Y %H:%M:%S')
end_date = datetime.strptime('20/02/2024 00:00:00', '%d/%m/%Y %H:%M:%S')

# %%
print(str(start_date.strftime("%Y%m%d%H%M%S")))
# Out:
# 20240210000000

# %%
num_of_days = (end_date - start_date).days+1
num_of_days
# Out:
# 11

# %%
currentday = end_date
previousday = end_date - timedelta(days=1)

f = Filters(
    keyword = "crypto",
    start_date = str(previousday.strftime("%Y%m%d")),
    end_date = str(currentday.strftime("%Y%m%d"))
)

gd = GdeltDoc()

# Search for articles matching the filters
articles = gd.article_search(f)
df = articles[(articles["language"] == 'English')]
df
# Out:
#                                                    url  \
# 0    https://www.newsbtc.com/news/company/crypto-on...
# 1    https://economictimes.indiatimes.com/markets/c...
# 3    https://cointelegraph.com/news/crypto-super-pa...
# 4    https://www.coindesk.com/markets/2024/02/19/bi...
# 5    https://www.pymnts.com/cryptocurrency/2024/cha...
# ..                                                 ...
# 245  https://www.modernreaders.com/news/2024/02/19/...
# 246  https://www.hedgeweek.com/sec-cyber-lapses-pos...
# 247  https://www.npr.org/2024/02/19/1232449119/ye-t...
# 248  https://dailyreporter.com/2024/02/19/crews-tak...
# 249  https://finance-commerce.com/2024/02/crews-sec...
#
#                                             url_mobile  \
# 0    https://www.newsbtc.com/news/company/crypto-on...
# 1    https://m.economictimes.com/markets/cryptocurr...
# 3
# 4    https://www.coindesk.com/markets/2024/02/19/bi...
# 5
# ..                                                 ...
# 245
# 246
# 247
# 248
# 249
#
#                                                  title          seendate  \
# 0    Crypto on the Rise : Who Are the Strongest Bel...  20240219T211500Z
# 1    Bitcoin : Small investors starting to tiptoe b...  20240219T020000Z
# 3      Flood of money  from crypto Super PACs could...  20240219T190000Z
# 4    Bitcoin ( BTC ) ETFs See Record $2 . 4B Weekly...  20240219T161500Z
# 5     Chainanalysis : Crypto Money Laundering Plummets  20240219T024500Z
# ..                                                 ...               ...
# 245  Kyber Network Crystal Legacy ( KNCL ) Reaches ...  20240219T020000Z
# 246  SEC cyber lapses pose risk to trading secrets ...  20240219T133000Z
# 247  Inside Kanye and Ty Dolla $ign  Vulture listen...  20240219T211500Z
# 248  Crews secure graffiti - scarred Los Angeles to...  20240219T231500Z
# 249  Crews secure Los Angeles towers left unfinishe...  20240220T000000Z
#
#                                            socialimage  \
# 0    https://www.newsbtc.com/wp-content/uploads/202...
# 1    https://img.etimg.com/thumb/msid-107805046,wid...
# 3    https://images.cointelegraph.com/cdn-cgi/image...
# 4    https://www.coindesk.com/resizer/ZbcDrB_CFh7PN...
# 5    https://www.pymnts.com/wp-content/uploads/2024...
# ..                                                 ...
# 245
# 246
# 247  https://media.npr.org/assets/img/2024/02/19/ye...
# 248  https://dailyreporter.com/files/2024/02/AP2404...
# 249  https://finance-commerce.com/files/2024/02/Gra...
#
#                            domain language   sourcecountry
# 0                     newsbtc.com  English   United States
# 1    economictimes.indiatimes.com  English           India
# 3               cointelegraph.com  English           China
# 4                    coindesk.com  English   United States
# 5                      pymnts.com  English   United States
# ..                            ...      ...             ...
# 245             modernreaders.com  English   United States
# 246                 hedgeweek.com  English  United Kingdom
# 247                       npr.org  English   United States
# 248             dailyreporter.com  English   United States
# 249          finance-commerce.com  English   United States
#
# [226 rows x 8 columns]

# %%
for i in range(num_of_days):
    currentday = end_date- timedelta(days=i)
    previousday = end_date- timedelta(days=i+1)
    print("start_date, end_date = ",previousday,currentday)
    for item in ['cryptocurrency', 
                 'cryptocurrencies',
                 'CBDC',
                 'Bitcoin',
                 'Ethereum',  
                 'BinanceCoin',
                 'crypto', 
                 'btc',
                 'eth', 
                 'USDT']:
        print(item)
        try:
            f = Filters(
                keyword = item,
                start_date = str(previousday.strftime("%Y%m%d")),
                end_date = str(currentday.strftime("%Y%m%d"))
            )

            gd = GdeltDoc()
            # Search for articles matching the filters
            articles = gd.article_search(f)
            articles = articles[(articles["language"] == 'English')]
            df = pd.concat([df, articles], axis=0)
            df = df.drop_duplicates(subset=['url'], keep='last')
            time.sleep(1)
        except:
            pass
    time.sleep(5) # Sleeping 5 seconds to avoid being blocked by Gdelt/Gdeltdoc
# Out:
# start_date, end_date =  2024-02-19 00:00:00 2024-02-20 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-18 00:00:00 2024-02-19 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-17 00:00:00 2024-02-18 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-16 00:00:00 2024-02-17 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-15 00:00:00 2024-02-16 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-14 00:00:00 2024-02-15 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-13 00:00:00 2024-02-14 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-12 00:00:00 2024-02-13 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-11 00:00:00 2024-02-12 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-10 00:00:00 2024-02-11 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-09 00:00:00 2024-02-10 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-08 00:00:00 2024-02-09 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-07 00:00:00 2024-02-08 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-06 00:00:00 2024-02-07 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-05 00:00:00 2024-02-06 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-04 00:00:00 2024-02-05 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-03 00:00:00 2024-02-04 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-02 00:00:00 2024-02-03 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-02-01 00:00:00 2024-02-02 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-01-31 00:00:00 2024-02-01 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-01-30 00:00:00 2024-01-31 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT
# start_date, end_date =  2024-01-29 00:00:00 2024-01-30 00:00:00
# cryptocurrency
# cryptocurrencies
# CBDC
# Bitcoin
# Ethereum
# BinanceCoin
# crypto
# btc
# eth
# USDT

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv("GA_data.csv", index=False)

# %%
df
# Out:
#                                                      url url_mobile  \
# 0      https://news.yahoo.com/ai-scams-missouri-warns...
# 1      https://www.americanbanker.com/opinion/regulat...
# 2                  https://biztoc.com/x/97e1450bfef84362
# 3                  https://biztoc.com/x/5c2110519540e5cf
# 4                  https://biztoc.com/x/2f038851769a9841
# ...                                                  ...        ...
# 13999  https://www.kilkennypeople.ie/news/national-ne...
# 14000  https://www.leitrimobserver.ie/news/national-n...
# 14001  https://www.donegallive.ie/news/national-news/...
# 14002  https://www.banklesstimes.com/news/2024/01/29/...
# 14003  https://www.news-expressky.com/lifestyles/ente...
#
#                                                    title          seendate  \
# 0      AI Scams : Missouri warns voices of loved ones...  20240219T204500Z
# 1      Regulators should reexamine their assumptions ...  20240219T194500Z
# 2      South Korean Political Party Eyes Crypto Revol...  20240219T130000Z
# 3      Unraveling the Mystery Behind XRP Price Underp...  20240219T103000Z
# 4      Cryptocurrency Rankings : Solana Claims the Co...  20240219T181500Z
# ...                                                  ...               ...
# 13999  Oliver Callan first day on new RTÉ show - feel...  20240129T151500Z
# 14000  Oliver Callan first day on new RTÉ show - feel...  20240129T151500Z
# 14001  Oliver Callan first day on new RTÉ show - feel...  20240129T151500Z
# 14002         RFK Jr . Joins Trump in Anti - CBDC Stance  20240129T141500Z
# 14003  Joni Mitchell to perform at Grammy Awards for ...  20240129T054500Z
#
#                                              socialimage              domain  \
# 0      https://media.zenfs.com/en/ktvi_articles_498/2...      news.yahoo.com
# 1      https://source-media-brightspot.s3.us-east-1.a...  americanbanker.com
# 2         https://c.biztoc.com/p/97e1450bfef84362/s.webp          biztoc.com
# 3         https://c.biztoc.com/p/5c2110519540e5cf/s.webp          biztoc.com
# 4         https://c.biztoc.com/p/2f038851769a9841/s.webp          biztoc.com
# ...                                                  ...                 ...
# 13999  https://www.kilkennypeople.ie/resizer/1200/700...   kilkennypeople.ie
# 14000  https://www.leitrimobserver.ie/resizer/1200/70...  leitrimobserver.ie
# 14001  https://www.donegallive.ie/resizer/1200/700/tr...      donegallive.ie
# 14002  https://cdn.banklesstimes.com/tr:f-jpg,w-1200,...   banklesstimes.com
# 14003  https://bloximages.chicago2.vip.townnews.com/n...  news-expressky.com
#
#       language  sourcecountry
# 0      English  United States
# 1      English  United States
# 2      English
# 3      English
# 4      English
# ...        ...            ...
# 13999  English        Ireland
# 14000  English        Ireland
# 14001  English
# 14002  English  United States
# 14003  English  United States
#
# [14004 rows x 8 columns]
